# %% [markdown]
# &nbsp;
#
# #  <center>The Umpire Model - Data</center>
# ## <center>Can we use Major League Baseball Statcast pitching metrics to classify balls and strikes?</center>
# ##### <center>University of Colorado Boulder | Introduction to Machine Learning: Supervised Learning - Final Project</center>
# ##### <center>Jeremy Hurley | October, 2024</center>
#
# &nbsp;
#
# ---
#
# &nbsp;

# %% [markdown]
# This notebook will import, clean and save a dataset for use in my final project.
#
# See the main notebook *'The Umpire Model'* for the remainder of the project.

# %% [markdown]
# # Data Acquisition:
# The pybaseball Python package was developed by James LeDoux. It pulls data from multiple data sources, including FanGraphs, Baseball Reference and Baseball Savant. It contains a vast amount of data from every MLB game played in the modern era. For more information on pybaseball, find it's GitHub repo [here](https://github.com/jldbc/pybaseball)
#
# This project starts by pulling all statcast data from the 2023 season.

# %%
import pybaseball as pb
import pandas as pd

# Pull statcast data for the entire 2023 MLB season
data = pb.statcast(start_dt='2023-03-30', end_dt='2023-10-01')

# Look at first few rows of data.
data.head()
# Out:
# This is a large query, it may take a moment to complete
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
#   0%|                                                                        | 0/186 [00:00<?, ?it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   1%|▎                                                               | 1/186 [00:01<03:31,  1.14s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   1%|▋                                                               | 2/186 [00:02<03:14,  1.06s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   2%|█                                                               | 3/186 [00:02<02:21,  1.29it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   2%|█▍                                                              | 4/186 [00:09<09:30,  3.14s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   3%|█▋                                                              | 5/186 [00:13<10:42,  3.55s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   4%|██▊                                                             | 8/186 [00:14<03:50,  1.29s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   5%|███▍                                                           | 10/186 [00:15<02:21,  1.24it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   6%|███▋                                                           | 11/186 [00:15<01:44,  1.68it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   6%|████                                                           | 12/186 [00:16<01:34,  1.85it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   7%|████▍                                                          | 13/186 [00:16<01:13,  2.34it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   8%|█████                                                          | 15/186 [00:16<00:57,  2.97it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   9%|█████▍                                                         | 16/186 [00:22<05:11,  1.83s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   9%|█████▊                                                         | 17/186 [00:23<04:37,  1.64s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  10%|██████                                                         | 18/186 [00:24<04:04,  1.45s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  10%|██████▍                                                        | 19/186 [00:26<04:30,  1.62s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  12%|███████▍                                                       | 22/186 [00:27<02:26,  1.12it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  13%|████████▏                                                      | 24/186 [00:29<02:16,  1.19it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  13%|████████▍                                                      | 25/186 [00:29<01:56,  1.38it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  15%|█████████▏                                                     | 27/186 [00:30<01:19,  1.99it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  15%|█████████▍                                                     | 28/186 [00:33<03:01,  1.15s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  16%|██████████▏                                                    | 30/186 [00:34<02:37,  1.01s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  17%|██████████▌                                                    | 31/186 [00:35<02:16,  1.14it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  17%|██████████▊                                                    | 32/186 [00:38<03:49,  1.49s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  18%|███████████▏                                                   | 33/186 [00:39<03:33,  1.40s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  18%|███████████▌                                                   | 34/186 [00:40<03:07,  1.23s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  20%|████████████▌                                                  | 37/186 [00:42<02:10,  1.14it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  20%|████████████▊                                                  | 38/186 [00:43<01:58,  1.25it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  21%|█████████████▏                                                 | 39/186 [00:43<01:32,  1.59it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  22%|█████████████▌                                                 | 40/186 [00:44<01:46,  1.36it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  22%|█████████████▉                                                 | 41/186 [00:45<02:05,  1.16it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  23%|██████████████▌                                                | 43/186 [00:48<02:29,  1.05s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
# ...
#  87%|█████████████████████████████████████████████████████▋        | 161/186 [03:02<00:37,  1.50s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  87%|██████████████████████████████████████████████████████        | 162/186 [03:04<00:36,  1.52s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  88%|██████████████████████████████████████████████████████▋       | 164/186 [03:07<00:32,  1.47s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  90%|███████████████████████████████████████████████████████▋      | 167/186 [03:09<00:17,  1.07it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  90%|████████████████████████████████████████████████████████      | 168/186 [03:10<00:15,  1.17it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  91%|████████████████████████████████████████████████████████▋     | 170/186 [03:14<00:20,  1.29s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  92%|█████████████████████████████████████████████████████████     | 171/186 [03:15<00:17,  1.19s/it]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  93%|█████████████████████████████████████████████████████████▋    | 173/186 [03:16<00:11,  1.09it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  94%|██████████████████████████████████████████████████████████▎   | 175/186 [03:17<00:07,  1.43it/s]C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# 100%|██████████████████████████████████████████████████████████████| 186/186 [03:26<00:00,  1.11s/it]
# C:\Users\hurle\OneDrive\MSDS_Colorado\DTSA 550X - CS Pathway\DTSA 5509 - Intro to Machine Learning\FinalProject\env\Lib\site-packages\pybaseball\statcast.py:85: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_data = pd.concat(dataframe_list, axis=0).convert_dtypes(convert_string=False)
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 2404         CH 2023-10-01           89.0           -2.8           5.59
# 2483         FF 2023-10-01           96.9           -2.4            5.9
# 2627         CH 2023-10-01           90.0          -2.93           5.56
# 2644         ST 2023-10-01           82.2          -3.09           5.55
# 2791         CH 2023-10-01           89.2          -2.87           5.58
#
#           player_name  batter  pitcher     events      description  ...  \
# 2404  Robertson, Nick  677008   687798  field_out    hit_into_play  ...
# 2483  Robertson, Nick  677008   687798        NaN             foul  ...
# 2627  Robertson, Nick  677008   687798        NaN             ball  ...
# 2644  Robertson, Nick  677008   687798        NaN             ball  ...
# 2791  Robertson, Nick  677008   687798        NaN  swinging_strike  ...
#
#       post_home_score  post_bat_score  post_fld_score  if_fielding_alignment  \
# 2404                1               1               6          Infield shade
# 2483                1               1               6          Infield shade
# 2627                1               1               6          Infield shade
# 2644                1               1               6          Infield shade
# 2791                1               1               6          Infield shade
#
#       of_fielding_alignment spin_axis delta_home_win_exp delta_run_exp  \
# 2404               Standard       250                0.0         -0.09
# 2483               Standard       211                0.0           0.0
# 2627               Standard       250                0.0         0.016
# 2644               Standard        58                0.0         0.009
# 2791               Standard       257                0.0        -0.023
#
#      bat_speed swing_length
# 2404      <NA>         <NA>
# 2483      <NA>         <NA>
# 2627      <NA>         <NA>
# 2644      <NA>         <NA>
# 2791      <NA>         <NA>
#
# [5 rows x 94 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 717945 entries, 2404 to 4456
# Data columns (total 94 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   pitch_type                       717674 non-null  object
#  1   game_date                        717945 non-null  datetime64[ns]
#  2   release_speed                    717673 non-null  Float64
#  3   release_pos_x                    717674 non-null  Float64
#  4   release_pos_z                    717674 non-null  Float64
#  5   player_name                      717945 non-null  object
#  6   batter                           717945 non-null  Int64
#  7   pitcher                          717945 non-null  Int64
#  8   events                           183773 non-null  object
#  9   description                      717945 non-null  object
#  10  spin_dir                         0 non-null       Int64
#  11  spin_rate_deprecated             0 non-null       Int64
#  12  break_angle_deprecated           0 non-null       Int64
#  13  break_length_deprecated          0 non-null       Int64
#  14  zone                             717674 non-null  Int64
#  15  des                              717945 non-null  object
#  16  game_type                        717945 non-null  object
#  17  stand                            717945 non-null  object
#  18  p_throws                         717945 non-null  object
#  19  home_team                        717945 non-null  object
#  20  away_team                        717945 non-null  object
#  21  type                             717945 non-null  object
#  22  hit_location                     160029 non-null  Int64
#  23  bb_type                          124234 non-null  object
#  24  balls                            717945 non-null  Int64
#  25  strikes                          717945 non-null  Int64
#  26  game_year                        717945 non-null  Int64
#  27  pfx_x                            717674 non-null  Float64
#  28  pfx_z                            717674 non-null  Float64
#  29  plate_x                          717674 non-null  Float64
#  30  plate_z                          717674 non-null  Float64
#  31  on_3b                            69419 non-null   Int64
#  32  on_2b                            137481 non-null  Int64
#  33  on_1b                            221293 non-null  Int64
#  34  outs_when_up                     717945 non-null  Int64
#  35  inning                           717945 non-null  Int64
#  36  inning_topbot                    717945 non-null  object
#  37  hc_x                             124179 non-null  Float64
#  38  hc_y                             124179 non-null  Float64
#  39  tfs_deprecated                   0 non-null       Int64
#  40  tfs_zulu_deprecated              0 non-null       Int64
#  41  fielder_2                        717945 non-null  Int64
#  42  umpire                           0 non-null       Int64
#  43  sv_id                            0 non-null       Int64
#  44  vx0                              717674 non-null  Float64
#  45  vy0                              717674 non-null  Float64
#  46  vz0                              717674 non-null  Float64
#  47  ax                               717674 non-null  Float64
#  48  ay                               717674 non-null  Float64
#  49  az                               717674 non-null  Float64
#  50  sz_top                           717674 non-null  Float64
#  51  sz_bot                           717674 non-null  Float64
#  52  hit_distance_sc                  238197 non-null  Int64
#  53  launch_speed                     236925 non-null  Float64
#  54  launch_angle                     237245 non-null  Int64
#  55  effective_speed                  716545 non-null  Float64
#  56  release_spin_rate                713633 non-null  Int64
#  57  release_extension                716643 non-null  Float64
#  58  game_pk                          717945 non-null  Int64
#  59  pitcher.1                        717945 non-null  Int64
#  60  fielder_2.1                      717945 non-null  Int64
#  61  fielder_3                        717945 non-null  Int64
#  62  fielder_4                        717945 non-null  Int64
#  63  fielder_5                        717945 non-null  Int64
#  64  fielder_6                        717945 non-null  Int64
#  65  fielder_7                        717945 non-null  Int64
#  66  fielder_8                        717945 non-null  Int64
#  67  fielder_9                        717945 non-null  Int64
#  68  release_pos_y                    717674 non-null  Float64
#  69  estimated_ba_using_speedangle    123874 non-null  Float64
#  70  estimated_woba_using_speedangle  182620 non-null  Float64
#  71  woba_value                       183773 non-null  Float64
#  72  woba_denom                       183413 non-null  Int64
#  73  babip_value                      183773 non-null  Int64
#  74  iso_value                        183773 non-null  Int64
#  75  launch_speed_angle               123874 non-null  Int64
#  76  at_bat_number                    717945 non-null  Int64
#  77  pitch_number                     717945 non-null  Int64
#  78  pitch_name                       717674 non-null  object
#  79  home_score                       717945 non-null  Int64
#  80  away_score                       717945 non-null  Int64
#  81  bat_score                        717945 non-null  Int64
#  82  fld_score                        717945 non-null  Int64
#  83  post_away_score                  717945 non-null  Int64
#  84  post_home_score                  717945 non-null  Int64
#  85  post_bat_score                   717945 non-null  Int64
#  86  post_fld_score                   717945 non-null  Int64
#  87  if_fielding_alignment            715493 non-null  object
#  88  of_fielding_alignment            715493 non-null  object
#  89  spin_axis                        713634 non-null  Int64
#  90  delta_home_win_exp               717945 non-null  Float64
#  91  delta_run_exp                    717891 non-null  Float64
#  92  bat_speed                        0 non-null       Int64
#  93  swing_length                     0 non-null       Int64
# dtypes: Float64(26), Int64(51), datetime64[ns](1), object(16)
# memory usage: 573.1+ MB

# %% [markdown]
# &nbsp;
#
# The previous two cells show that we have 717,945 rows and 94 columns of data.
#
# Next step is to clean and filter the data.
#
# &nbsp;
#
# ---
#
# &nbsp;

# %%
# get all unique values of the 'description' column to see how pybaseball categorizes the outcome of each pitch
print(data['description'].unique())
# Out:
# ['hit_into_play' 'foul' 'ball' 'swinging_strike' 'called_strike'
#  'foul_tip' 'blocked_ball' 'swinging_strike_blocked' 'hit_by_pitch'
#  'foul_bunt' 'missed_bunt' 'pitchout' 'bunt_foul_tip']

# %% [markdown]
# # Data Cleaning:
#
# As you can see above, statcast data on the entire 2023 season results in a massive amount of data. My approach to cleaning the data will be as follows:
#
# 1. Remove columns that are not relevant to our model, including player and score information.
#
# *I will keep situational information like the count and baserunners because I think further work can explore whether or not the strike zone changes based on the count (3-0 versus 0-2) or if there are runners on base. This will be discussed in the Discussion and Conclusions section.*
#
# 2. Remove rows where the outcome of the pitch was anything except for a ball or called_strike.
#
# *We can't judge a pitch to be a ball or strike by whether or not the batter swung at it. This project is meant to analyze how an umpire calls balls and strikes, therefore, we'll need to remove instances like 'swinging_strike', 'foul', ect.*
#
# 3. Remove rows with missing values in columns that will be key to our model.
#
# *Will start with 'plate_x', 'plate_z' and 'type', then analyze the state of other columns to see if further action is needed.*
#
# Finally, considering the size of the initial dataset and the amount of time it took to download, I'll save the cleaned data set to a .csv file for future use.

# %%
# Filter data for relevant columns
cleaned_data = data[['plate_x', 'plate_z', 'pitch_type', 'zone', 'sz_top', 'sz_bot', 'type', 'release_speed', 'release_pos_x', 'release_pos_z', 'release_pos_y', 'description', 'stand', 'p_throws', 'balls', 'strikes', 'pfx_x', 'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'pitch_name']]

# Look at cleaned data 
cleaned_data.head()
# Out:
#      plate_x  plate_z pitch_type  zone  sz_top  sz_bot type  release_speed  \
# 2404    0.33     2.01         CH     9    3.81    1.74    X           89.0
# 2483    0.09     2.71         FF     5    3.81    1.74    S           96.9
# 2627   -0.24     0.53         CH    13    3.71    1.78    B           90.0
# 2644    0.81     0.49         ST    14    3.78    1.74    B           82.2
# 2791   -0.78     2.05         CH     7    3.81    1.74    S           89.2
#
#       release_pos_x  release_pos_z  ...  strikes pfx_x pfx_z plate_x  plate_z  \
# 2404           -2.8           5.59  ...        2 -1.53  0.33    0.33     2.01
# 2483           -2.4            5.9  ...        2 -0.76  1.36    0.09     2.71
# 2627          -2.93           5.56  ...        2 -1.65  0.36   -0.24     0.53
# 2644          -3.09           5.55  ...        2  1.43  0.28    0.81     0.49
# 2791          -2.87           5.58  ...        1 -1.49  0.31   -0.78     2.05
#
#       on_3b  on_2b  on_1b  outs_when_up       pitch_name
# 2404   <NA>   <NA>   <NA>             2         Changeup
# 2483   <NA>   <NA>   <NA>             2  4-Seam Fastball
# 2627   <NA>   <NA>   <NA>             2         Changeup
# 2644   <NA>   <NA>   <NA>             2          Sweeper
# 2791   <NA>   <NA>   <NA>             2         Changeup
#
# [5 rows x 25 columns]

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 717945 entries, 2404 to 4456
# Data columns (total 25 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   plate_x        717674 non-null  Float64
#  1   plate_z        717674 non-null  Float64
#  2   pitch_type     717674 non-null  object
#  3   zone           717674 non-null  Int64
#  4   sz_top         717674 non-null  Float64
#  5   sz_bot         717674 non-null  Float64
#  6   type           717945 non-null  object
#  7   release_speed  717673 non-null  Float64
#  8   release_pos_x  717674 non-null  Float64
#  9   release_pos_z  717674 non-null  Float64
#  10  release_pos_y  717674 non-null  Float64
#  11  description    717945 non-null  object
#  12  stand          717945 non-null  object
#  13  p_throws       717945 non-null  object
#  14  balls          717945 non-null  Int64
#  15  strikes        717945 non-null  Int64
#  16  pfx_x          717674 non-null  Float64
#  17  pfx_z          717674 non-null  Float64
#  18  plate_x        717674 non-null  Float64
#  19  plate_z        717674 non-null  Float64
#  20  on_3b          69419 non-null   Int64
#  21  on_2b          137481 non-null  Int64
#  22  on_1b          221293 non-null  Int64
#  23  outs_when_up   717945 non-null  Int64
#  24  pitch_name     717674 non-null  object
# dtypes: Float64(12), Int64(7), object(6)
# memory usage: 155.4+ MB

# %%
# Filter out rows where the outcome was not a called ball or called strike
cleaned_data = cleaned_data[cleaned_data['description'].isin(['ball', 'called_strike'])]
#Encode 'type' column as numeric: 1 for strike, 0 for balls
cleaned_data['type'] = cleaned_data['type'].apply(lambda x: 1 if x == 'S' else 0)

# Check the data
cleaned_data.head()
# Out:
#      plate_x  plate_z pitch_type  zone  sz_top  sz_bot  type  release_speed  \
# 2627   -0.24     0.53         CH    13    3.71    1.78     0           90.0
# 2644    0.81     0.49         ST    14    3.78    1.74     0           82.2
# 3228   -1.84     4.08         ST    11    3.07    1.51     0           79.4
# 3391    1.13     0.97         ST    14     3.1    1.46     0           82.9
# 3536   -0.65     2.34         ST     4    3.07    1.48     1           82.0
#
#       release_pos_x  release_pos_z  ...  strikes pfx_x pfx_z plate_x  plate_z  \
# 2627          -2.93           5.56  ...        2 -1.65  0.36   -0.24     0.53
# 2644          -3.09           5.55  ...        2  1.43  0.28    0.81     0.49
# 3228          -2.96           5.67  ...        2  1.66  -0.2   -1.84     4.08
# 3391          -2.82           5.66  ...        2  1.16  0.01    1.13     0.97
# 3536           -3.0           5.69  ...        1  1.45  0.06   -0.65     2.34
#
#       on_3b  on_2b  on_1b  outs_when_up  pitch_name
# 2627   <NA>   <NA>   <NA>             2    Changeup
# 2644   <NA>   <NA>   <NA>             2     Sweeper
# 3228   <NA>   <NA>   <NA>             1     Sweeper
# 3391   <NA>   <NA>   <NA>             1     Sweeper
# 3536   <NA>   <NA>   <NA>             1     Sweeper
#
# [5 rows x 25 columns]

# %%
# Remove rows with missing critical info
cleaned_data = cleaned_data.dropna(subset=['plate_x', 'plate_z', 'type'])
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 358481 entries, 2627 to 4456
# Data columns (total 25 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   plate_x        358481 non-null  Float64
#  1   plate_z        358481 non-null  Float64
#  2   pitch_type     358481 non-null  object
#  3   zone           358481 non-null  Int64
#  4   sz_top         358481 non-null  Float64
#  5   sz_bot         358481 non-null  Float64
#  6   type           358481 non-null  int64
#  7   release_speed  358480 non-null  Float64
#  8   release_pos_x  358481 non-null  Float64
#  9   release_pos_z  358481 non-null  Float64
#  10  release_pos_y  358481 non-null  Float64
#  11  description    358481 non-null  object
#  12  stand          358481 non-null  object
#  13  p_throws       358481 non-null  object
#  14  balls          358481 non-null  Int64
#  15  strikes        358481 non-null  Int64
#  16  pfx_x          358481 non-null  Float64
#  17  pfx_z          358481 non-null  Float64
#  18  plate_x        358481 non-null  Float64
#  19  plate_z        358481 non-null  Float64
#  20  on_3b          30427 non-null   Int64
#  21  on_2b          62147 non-null   Int64
#  22  on_1b          103401 non-null  Int64
#  23  outs_when_up   358481 non-null  Int64
#  24  pitch_name     358481 non-null  object
# dtypes: Float64(12), Int64(7), int64(1), object(5)
# memory usage: 77.6+ MB

# %% [markdown]
# &nbsp;
#
# ---
#
#
# # Data Save:
# As you can see in the above cell, we've cleaned the original 94 columns X 717945 rows worth of data to 25 columns X 358481 rows of data. We've filtered out unneeded columns and rows and removed rows with missing data. Further examination of the .info() above shows that, with the exception of on_base columns, which we would expect to be incomplete, all other rows are complete.
#
# I will now save this dataset as a CSV file to have easier access to it in the future and continue to project in a new notebook.

# %%
# Save the dataset to a CSV file
cleaned_data.to_csv('2023_strike_ball_data.csv', index=False)
